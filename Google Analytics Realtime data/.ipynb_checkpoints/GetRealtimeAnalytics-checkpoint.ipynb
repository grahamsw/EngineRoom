# %%
from apiclient.discovery import build
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd

key_file_location = r'C:\Users\graha\Downloads\FFOCREPORTING-a9a4a73210dd.json'
profile_id = 'ga:175168708' 


def get_service(key_file_location):
    api_name='analytics'
    api_version='v3'
    scope = 'https://www.googleapis.com/auth/analytics.readonly'
    credentials = ServiceAccountCredentials.from_json_keyfile_name(
            key_file_location, scopes=[scope])
    return build(api_name, api_version, credentials=credentials)

def get_results(service, profile_id, metrics, dimensions):
    # Use the Analytics Service Object to query the Core Reporting API
    # for the number of sessions within the past seven days.
    ret = service.data().realtime().get(
            ids=profile_id,
            metrics=metrics,
            dimensions=dimensions).execute()
    return pd.DataFrame(ret['rows'], columns=[r['name'] for r in ret['columnHeaders']])


def makeMetricGetter(key_file_location, profile_id, metrics, dimensions):
    def getMetrics():
        service = get_service(key_file_location)
        return get_results(service, profile_id, metrics, dimensions)
    return getMetrics

# %%
   
pageMetrics = makeMetricGetter(key_file_location, profile_id,
                                    'rt:pageviews', 
                                    'rt:pageTitle, rt:pagePath')



userMetrics = makeMetricGetter(key_file_location, profile_id,
                               'rt:activeUsers',
                               'rt:userType')

# %%
pageMetrics()
# Out:
#                                          rt:pageTitle  \
# 0   American tipping is rooted in slavery—and it s...
# 1                 Board of Trustees / Ford Foundation
# 2                           Careers / Ford Foundation
# 3                    Carlton Turner / Ford Foundation
# 4            Challenging inequality / Ford Foundation
# 5   Diversity, equity, and inclusion / Ford Founda...
# 6                Equals Change Blog / Ford Foundation
# 7                       Exhibitions / Ford Foundation
# 8           Ford Foundation Gallery / Ford Foundation
# 9                        Grants All / Ford Foundation
# 10                  Grants database / Ford Foundation
# 11                             Home / Ford Foundation
# 12                             Home / Ford Foundation
# 13                  Idea Submission / Ford Foundation
# 14  Individuals seeking fellowships / Ford Foundation
# 15  International Fellowships Program / Ford Found...
# 16                JustFilms inquiry / Ford Foundation
# 17  Michelle Alexander on racial justice, mass inc...
# 18                     Noorain Khan / Ford Foundation
# 19    Other philanthropic resources / Ford Foundation
# 20                       Our grants / Ford Foundation
# 21  Roads and Bridges: The Unseen Labor Behind Our...
# 22                           Search / Ford Foundation
# 23  The Ford Foundation Center for Social Justice ...
# 24    Toward a new gospel of wealth / Ford Foundation
# 25              Visitor information / Ford Foundation
# 26                      West Africa / Ford Foundation
#
#                                           rt:pagePath rt:pageviews
# 0   /ideas/equals-change-blog/posts/american-tippi...            2
# 1                    /about/people/board-of-trustees/            1
# 2                                     /about/careers/            1
# 3   /campaigns/the-art-of-change-meet-our-fellows/...            1
# 4                       /work/challenging-inequality/            1
# 5       /about/people/diversity-equity-and-inclusion/            1
# 6                          /ideas/equals-change-blog/            1
# 7   /about/the-ford-foundation-center-for-social-j...            1
# 8   /about/the-ford-foundation-center-for-social-j...            3
# 9        /work/our-grants/grants-database/grants-all/            1
# 10                  /work/our-grants/grants-database/            2
# 11                                                  /            6
# 12                                      /?filter=News            1
# 13                  /work/our-grants/idea-submission/            1
# 14  /work/our-grants/individuals-seeking-fellowships/            3
# 15  /work/learning-and-impact/international-fellow...            2
# 16      /work/our-grants/justfilms/justfilms-inquiry/            1
# 17  /ideas/equals-change-blog/posts/michelle-alexa...            1
# 18                        /about/people/noorain-khan/            1
# 19    /work/our-grants/other-philanthropic-resources/            1
# 20                                  /work/our-grants/            6
# 21  /about/library/reports-and-studies/roads-and-b...            2
# 22         /search/?q=ford+foundation+fellowships&p=0            1
# 23  /about/the-ford-foundation-center-for-social-j...            1
# 24  /ideas/equals-change-blog/posts/toward-a-new-g...            4
# 25  /about/the-ford-foundation-center-for-social-j...            1
# 26            /our-work-around-the-world/west-africa/            1

# %%
userMetrics()
# Out:
#   rt:userType rt:activeUsers
# 0         NEW              6
