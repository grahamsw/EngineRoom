# %%
from apiclient.discovery import build
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd

def get_service(key_file_location):
    api_name='analytics'
    api_version='v3'
    scope = 'https://www.googleapis.com/auth/analytics.readonly'
    credentials = ServiceAccountCredentials.from_json_keyfile_name(
            key_file_location, scopes=[scope])
    return build(api_name, api_version, credentials=credentials)

def get_results(service, profile_id, metrics, dimensions):
    # Use the Analytics Service Object to query the Core Reporting API
    # for the number of sessions within the past seven days.
    ret = service.data().realtime().get(
            ids=profile_id,
            metrics=metrics,
            dimensions=dimensions).execute()
    return pd.DataFrame(ret['rows'], columns=[r['name'] for r in ret['columnHeaders']])

def makeMetricGetter(key_file_location, profile_id, metrics, dimensions):
    def getMetrics():
        service = get_service(key_file_location)
        return get_results(service, profile_id, metrics, dimensions)
    return getMetrics

# %%
key_file_location = r'C:\Users\graha\Downloads\FFOCREPORTING-a9a4a73210dd.json'
profile_id = 'ga:175168708' 

pageMetrics = makeMetricGetter(key_file_location, profile_id,
                                    'rt:pageviews', 
                                    'rt:pageTitle, rt:pagePath')

userMetrics = makeMetricGetter(key_file_location, profile_id,
                               'rt:activeUsers',
                               'rt:userType, rt:deviceCategory')

eventMetrics = makeMetricGetter(key_file_location, profile_id,
                               'rt:totalEvents',
                               'rt:eventAction,rt:eventCategory,rt:eventLabel')

# %%
pageMetrics()
# Out:
#                                          rt:pageTitle  \
# 0   #PopJustice: When pop culture meets social jus...
# 1                                           (not set)
# 2   A brief history of Ford Foundation's support f...
# 3   A new look for affordable housing / Ford Found...
# 4                        About Ford / Ford Foundation
# 5   American tipping is rooted in slavery—and it s...
# 6   American tipping is rooted in slavery—and it s...
# 7   American tipping is rooted in slavery—and it s...
# 8   An influx of refugees brings not only challeng...
# 9                        Anna Wadia / Ford Foundation
# 10                           Brazil / Ford Foundation
# 11                          Careers / Ford Foundation
# 12                    Chimene Okere / Ford Foundation
# 13                Cities and states / Ford Foundation
# 14  Civic Engagement and Government / Ford Foundation
# 15   Creativity and Free Expression / Ford Foundation
# 16                    Darren Walker / Ford Foundation
# 17                    Diane Samuels / Ford Foundation
# 18               Equals Change Blog / Ford Foundation
# 19                       Ethan Frey / Ford Foundation
# 20          Ford Foundation Gallery / Ford Foundation
# 21  Gender, Racial, and Ethnic Justice / Ford Foun...
# 22                     Grant makers / Ford Foundation
# 23                     Grant makers / Ford Foundation
# 24                       Grants All / Ford Foundation
# 25                Hilary Pennington / Ford Foundation
# 26                             Home / Ford Foundation
# 27                             Home / Ford Foundation
# 28                  Idea Submission / Ford Foundation
# 29      India, Nepal, and Sri Lanka / Ford Foundation
# 30  Individuals seeking fellowships / Ford Foundation
# 42                               /search/?q=Tibet&p=0            1
# 43                               /search/?q=china&p=0            1
# 44                      /search/?q=donativos+2019&p=0            2
# 45    /search/?q=how+ford+fundation+give+me+money&p=0            1
# 46                          /search/?q=money+2019&p=0            2
# 47  /about/careers/the-ford-foundation-internship-...            1
# 48          /our-work-around-the-world/united-states/            1
# 49       /ideas/ford-forum/your-american-dream-score/            1

# %%
userMetrics()
# Out:
#   rt:userType rt:deviceCategory rt:activeUsers
# 0         NEW           DESKTOP              7
# 1         NEW            MOBILE              3

# %%
eventMetrics()
# Out:
#          rt:eventAction          rt:eventCategory  \
# 0                   100                    Scroll
# 1                   100                    Scroll
# 2                   100                    Scroll
# 3                   100                    Scroll
# 4                   100                    Scroll
# 5                    25                    Scroll
# 6                    25                    Scroll
# 7                    25                    Scroll
# 8                    25                    Scroll
# 9                    25                    Scroll
# 10                   25                    Scroll
# 11                   25                    Scroll
# 12                   25                    Scroll
# 13                   25                    Scroll
# 14                   25                    Scroll
# 15                   25                    Scroll
# 16                   25                    Scroll
# 17                   25                    Scroll
# 18                   25                    Scroll
# 19                   25                    Scroll
# 20                   25                    Scroll
# 21                   25                    Scroll
# 22                   25                    Scroll
# 23                   25                    Scroll
# 24                   25                    Scroll
# 25                   25                    Scroll
# 26                   25                    Scroll
# 27                   25                    Scroll
# 28                   25                    Scroll
# 29                   25                    Scroll
# ..                  ...                       ...
# 63                   50                    Scroll
# 64                   75                    Scroll
# 65                   75                    Scroll
# 66                   75                    Scroll
# 67                   75                    Scroll
# 68                   75                    Scroll
# 69                   75                    Scroll
# 70                   75                    Scroll
# 71                   75                    Scroll
# 72                   75                    Scroll
# 73                   75                    Scroll
# 74                   75                    Scroll
# 75                   75                    Scroll
# 76                   75                    Scroll
# 77                   75                    Scroll
# 78                   75                    Scroll
# 79        Career Portal       Outbound Link Click
# 80  Grant Detail Expand  Grant Search Interaction
# 81  Grant Detail Expand  Grant Search Interaction
# 82  Grant Detail Expand  Grant Search Interaction
# 83  Grant Detail Expand  Grant Search Interaction
# 84  Grant Detail Expand  Grant Search Interaction
# 85  Grant Detail Expand  Grant Search Interaction
# 86  Grant Detail Expand  Grant Search Interaction
# 87  Grant Detail Expand  Grant Search Interaction
# 88  Grant Detail Expand  Grant Search Interaction
# 89  Grant Detail Expand  Grant Search Interaction
# 90  Grant Detail Expand  Grant Search Interaction
# 91             LinkedIn             Content Share
# 92              Twitter             Content Share
#
#                                         rt:eventLabel rt:totalEvents
# 0                          https://www.fordfound.org/              1
# 1       https://www.fordfoundation.org/about/careers/              1
# 2   https://www.fordfoundation.org/work/challengin...              1
# 3   https://www.fordfoundation.org/work/our-grants...              1
# 4   https://www.fordfoundation.org/work/our-grants...              1
# 5                          https://www.fordfound.org/              1
# 6                     https://www.fordfoundation.org/              3
# 7   https://www.fordfoundation.org/about/about-for...              1
# 8   https://www.fordfoundation.org/about/about-for...              1
# 9       https://www.fordfoundation.org/about/careers/              3
# 10  https://www.fordfoundation.org/about/careers/t...              1
# 11       https://www.fordfoundation.org/about/people/              3
# 12  https://www.fordfoundation.org/about/people/an...              1
# 13  https://www.fordfoundation.org/about/people/bo...              1
# 14  https://www.fordfoundation.org/about/people/ch...              1
# 15  https://www.fordfoundation.org/about/people/et...              1
# 16  https://www.fordfoundation.org/about/people/gr...              1
# 17  https://www.fordfoundation.org/about/people/gr...              1
# 18  https://www.fordfoundation.org/about/people/je...              1
# 19  https://www.fordfoundation.org/about/people/jo...              1
# 20  https://www.fordfoundation.org/about/people/ma...              1
# 21  https://www.fordfoundation.org/about/people/of...              1
# 22  https://www.fordfoundation.org/about/people/ra...              1
# 23  https://www.fordfoundation.org/about/the-ford-...              2
# 24  https://www.fordfoundation.org/about/the-ford-...              2
# 25  https://www.fordfoundation.org/about/the-ford-...              1
# 26  https://www.fordfoundation.org/campaigns/early...              1
# 27  https://www.fordfoundation.org/ideas/equals-ch...              1
# 28  https://www.fordfoundation.org/ideas/equals-ch...              2
# 29  https://www.fordfoundation.org/ideas/equals-ch...              1
# ..                                                ...            ...
# 63  https://www.fordfoundation.org/work/our-grants...              1
# 64                         https://www.fordfound.org/              1
# 65                    https://www.fordfoundation.org/              1
# 66      https://www.fordfoundation.org/about/careers/              1
# 67       https://www.fordfoundation.org/about/people/              1
# 68  https://www.fordfoundation.org/about/people/gr...              1
# 69  https://www.fordfoundation.org/about/people/gr...              1
# 70  https://www.fordfoundation.org/about/people/of...              1
# 71  https://www.fordfoundation.org/about/the-ford-...              1
# 72  https://www.fordfoundation.org/work/challengin...              1
# 73  https://www.fordfoundation.org/work/learning-a...              1
# 74    https://www.fordfoundation.org/work/our-grants/              1
# 75  https://www.fordfoundation.org/work/our-grants...              1
# 76  https://www.fordfoundation.org/work/our-grants...              1
# 77  https://www.fordfoundation.org/work/our-grants...              1
# 78  https://www.fordfoundation.org/work/our-grants...              1
# 79                                   Current Openings              2
# 80                                       grant-130648              1
# 81                                       grant-131796              1
# 82                                       grant-132072              1
# 83                                       grant-132228              1
# 84                                       grant-132268              1
# 85                                       grant-132548              1
# 86                                       grant-132597              1
# 87                                       grant-132887              1
# 88                                       grant-132888              1
# 89                                       grant-132933              1
# 90                                       grant-132984              1
# 91  https://www.fordfoundation.org/about/people/je...              1
# 92                 /about/people/jessica-dalton-rees/              1
#
# [93 rows x 4 columns]
